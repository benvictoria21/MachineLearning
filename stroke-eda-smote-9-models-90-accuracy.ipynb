# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import tensorflow as tf
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings("ignore")

# %%
dataset = pd.read_csv("https://raw.githubusercontent.com/benvictoria17/MachineLearning/master/dataset/%20Stroke%20Prediction%20Dataset/healthcare-dataset-stroke-data.csv")

# %%
dataset
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
dataset.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
dataset.bmi.replace(to_replace=np.nan, value=dataset.bmi.mean(), inplace=True)

# %%
dataset.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
dataset.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  5110.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.698018     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.800000     0.000000
# 50%            91.885000    28.400000     0.000000
# 75%           114.090000    32.800000     0.000000
# max           271.740000    97.600000     1.000000

# %%
dataset.corr()
# Out:
#                          id       age  hypertension  heart_disease  \
# id                 1.000000  0.003538      0.003550      -0.001296
# age                0.003538  1.000000      0.276398       0.263796
# hypertension       0.003550  0.276398      1.000000       0.108306
# heart_disease     -0.001296  0.263796      0.108306       1.000000
# avg_glucose_level  0.001092  0.238171      0.174474       0.161857
# bmi                0.002999  0.325942      0.160189       0.038899
# stroke             0.006388  0.245257      0.127904       0.134914
#
#                    avg_glucose_level       bmi    stroke
# id                          0.001092  0.002999  0.006388
# age                         0.238171  0.325942  0.245257
# hypertension                0.174474  0.160189  0.127904
# heart_disease               0.161857  0.038899  0.134914
# avg_glucose_level           1.000000  0.168751  0.131945
# bmi                         0.168751  1.000000  0.038947
# stroke                      0.131945  0.038947  1.000000

# %%
# Compute the correlation matrix
corr = dataset.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %%
print(dataset.gender.value_counts())
sns.set_theme(style="darkgrid")
ax = sns.countplot(data=dataset, x="gender")
plt.show()
# Out:
# Female    2994
# Male      2115
# Other        1
# Name: gender, dtype: int64

# %%
print(dataset.hypertension.value_counts())
sns.set_theme(style="darkgrid")
ax = sns.countplot(data=dataset, x="hypertension")
plt.show()
# Out:
# 0    4612
# 1     498
# Name: hypertension, dtype: int64

# %%
print(dataset.ever_married.value_counts())
sns.set_theme(style="darkgrid")
ax = sns.countplot(data=dataset, x="ever_married")
plt.show()
# Out:
# Yes    3353
# No     1757
# Name: ever_married, dtype: int64

# %%
print(dataset.work_type.value_counts())
sns.set_theme(style="darkgrid")
ax = sns.countplot(data=dataset, x="work_type")
plt.show()
# Out:
# Private          2925
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: work_type, dtype: int64

# %%
print(dataset.work_type.value_counts())
sns.set_theme(style="darkgrid")
ax = sns.countplot(data=dataset, x="work_type")
plt.show()
# Out:
# Private          2925
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: work_type, dtype: int64

# %%
print(dataset.Residence_type.value_counts())
sns.set_theme(style="darkgrid")
ax = sns.countplot(data=dataset, x="Residence_type")
plt.show()
# Out:
# Urban    2596
# Rural    2514
# Name: Residence_type, dtype: int64

# %%
print(dataset.smoking_status.value_counts())
sns.set_theme(style="darkgrid")
ax = sns.countplot(data=dataset, x="smoking_status")
ax.set_xticklabels(ax.get_xticklabels(), fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: smoking_status, dtype: int64

# %%
print(dataset.stroke.value_counts())
sns.set_theme(style="darkgrid")
ax = sns.countplot(data=dataset, x="stroke")
plt.show()
# Out:
# 0    4861
# 1     249
# Name: stroke, dtype: int64

# %%
fig = plt.figure(figsize=(7,7))
sns.distplot(dataset.avg_glucose_level, color="green", label="avg_glucose_level", kde= True)
plt.legend()

# %%
fig = plt.figure(figsize=(7,7))
sns.distplot(dataset.bmi, color="orange", label="bmi", kde= True)
plt.legend()

# %%
plt.figure(figsize=(12,10))

sns.distplot(dataset[dataset['stroke'] == 0]["bmi"], color='green') # No Stroke - green
sns.distplot(dataset[dataset['stroke'] == 1]["bmi"], color='red') # Stroke - Red

plt.title('No Stroke vs Stroke by BMI', fontsize=15)
plt.xlim([10,100])
plt.show()

# %%
plt.figure(figsize=(12,10))

sns.distplot(dataset[dataset['stroke'] == 0]["age"], color='green') # No Stroke - green
sns.distplot(dataset[dataset['stroke'] == 1]["age"], color='red') # Stroke - Red

plt.title('No Stroke vs Stroke by Age', fontsize=15)
plt.xlim([18,100])
plt.show()

# %%
plt.figure(figsize=(12,10))

sns.distplot(dataset[dataset['stroke'] == 0]["avg_glucose_level"], color='green') # No Stroke - green
sns.distplot(dataset[dataset['stroke'] == 1]["avg_glucose_level"], color='red') # Stroke - Red

plt.title('No Stroke vs Stroke by Avg. Glucose Level', fontsize=15)
plt.xlim([30,330])
plt.show()

# %%
plt.figure(figsize=(12,10))

sns.distplot(dataset[dataset['stroke'] == 0]["age"], color='green') # No Stroke - green
sns.distplot(dataset[dataset['stroke'] == 1]["age"], color='red') # Stroke - Red

plt.title('No Stroke vs Stroke by Age', fontsize=15)
plt.xlim([18,100])
plt.show()

# %%
fig = plt.figure(figsize=(7,7))
graph = sns.scatterplot(data=dataset, x="age", y="bmi", hue='gender')
graph.axhline(y= 25, linewidth=4, color='r', linestyle= '--')
plt.show()

# %%
fig = plt.figure(figsize=(7,7))
graph = sns.scatterplot(data=dataset, x="age", y="avg_glucose_level", hue='gender')
graph.axhline(y= 150, linewidth=4, color='r', linestyle= '--')
plt.show()

# %%
plt.figure(figsize=(13,13))
sns.set_theme(style="darkgrid")
plt.subplot(2,3,1)
sns.violinplot(x = 'gender', y = 'stroke', data = dataset)
plt.subplot(2,3,2)
sns.violinplot(x = 'hypertension', y = 'stroke', data = dataset)
plt.subplot(2,3,3)
sns.violinplot(x = 'heart_disease', y = 'stroke', data = dataset)
plt.subplot(2,3,4)
sns.violinplot(x = 'ever_married', y = 'stroke', data = dataset)
plt.subplot(2,3,5)
sns.violinplot(x = 'work_type', y = 'stroke', data = dataset)
plt.xticks(fontsize=9, rotation=45)
plt.subplot(2,3,6)
sns.violinplot(x = 'Residence_type', y = 'stroke', data = dataset)
plt.show()

# %%
fig = plt.figure(figsize=(10,10))
sns.pairplot(dataset)
plt.show()

# %%
x = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values
x
# Out:
# array([['Male', 67.0, 0, ..., 228.69, 36.6, 'formerly smoked'],
#        ['Female', 61.0, 0, ..., 202.21, 28.893236911794673,
#         'never smoked'],
#        ['Male', 80.0, 0, ..., 105.92, 32.5, 'never smoked'],
#        ...,
#        ['Female', 35.0, 0, ..., 82.99, 30.6, 'never smoked'],
#        ['Male', 51.0, 0, ..., 166.29, 25.6, 'formerly smoked'],
#        ['Female', 44.0, 0, ..., 85.28, 26.2, 'Unknown']], dtype=object)

# %%
y
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers= [('encoder', OneHotEncoder(), [0,5,9])], remainder= 'passthrough')
x = np.array(ct.fit_transform(x))
x
# Out:
# array([[0.0, 1.0, 0.0, ..., 'Urban', 228.69, 36.6],
#        [1.0, 0.0, 0.0, ..., 'Rural', 202.21, 28.893236911794673],
#        [0.0, 1.0, 0.0, ..., 'Rural', 105.92, 32.5],
#        ...,
#        [1.0, 0.0, 0.0, ..., 'Rural', 82.99, 30.6],
#        [0.0, 1.0, 0.0, ..., 'Rural', 166.29, 25.6],
#        [1.0, 0.0, 0.0, ..., 'Urban', 85.28, 26.2]], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
x[:, 15] = le.fit_transform(x[:, 15])
x[:, 16] = le.fit_transform(x[:, 16])
x
# Out:
# array([[0.0, 1.0, 0.0, ..., 1, 228.69, 36.6],
#        [1.0, 0.0, 0.0, ..., 0, 202.21, 28.893236911794673],
#        [0.0, 1.0, 0.0, ..., 0, 105.92, 32.5],
#        ...,
#        [1.0, 0.0, 0.0, ..., 0, 82.99, 30.6],
#        [0.0, 1.0, 0.0, ..., 0, 166.29, 25.6],
#        [1.0, 0.0, 0.0, ..., 1, 85.28, 26.2]], dtype=object)

# %%
print('Shape of X: ', x.shape)
print('Shape of Y: ', y.shape)
# Out:
# Shape of X:  (5110, 19)
# Shape of Y:  (5110,)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.2, random_state= 0)
print("Number transactions x_train dataset: ", x_train.shape)
print("Number transactions y_train dataset: ", y_train.shape)
print("Number transactions x_test dataset: ", x_test.shape)
print("Number transactions y_test dataset: ", y_test.shape)
# Out:
# Number transactions x_train dataset:  (4088, 19)
# Number transactions y_train dataset:  (4088,)
# Number transactions x_test dataset:  (1022, 19)
# Number transactions y_test dataset:  (1022,)

# %%
from sklearn.preprocessing import StandardScaler 
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
from imblearn.over_sampling import SMOTE
print("Before OverSampling, counts of label '1': {}".format(sum(y_train==1)))
print("Before OverSampling, counts of label '0': {} \n".format(sum(y_train==0)))

sm = SMOTE(random_state=2)
x_train_res, y_train_res = sm.fit_resample(x_train, y_train.ravel())

print('After OverSampling, the shape of train_X: {}'.format(x_train_res.shape))
print('After OverSampling, the shape of train_y: {} \n'.format(y_train_res.shape))

print("After OverSampling, counts of label '1': {}".format(sum(y_train_res==1)))
print("After OverSampling, counts of label '0': {}".format(sum(y_train_res==0)))
# Out:
# Before OverSampling, counts of label '1': 195
# Before OverSampling, counts of label '0': 3893
#
# After OverSampling, the shape of train_X: (7786, 19)
# After OverSampling, the shape of train_y: (7786,)
#
# After OverSampling, counts of label '1': 3893
# After OverSampling, counts of label '0': 3893

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score, ConfusionMatrixDisplay, precision_score, recall_score, f1_score, classification_report, roc_curve, plot_roc_curve, auc, precision_recall_curve, plot_precision_recall_curve, average_precision_score
from sklearn.model_selection import cross_val_score
models = []
models.append(['Logistic Regreesion', LogisticRegression(random_state=0)])
models.append(['SVM', SVC(random_state=0)])
models.append(['KNeighbors', KNeighborsClassifier()])
models.append(['GaussianNB', GaussianNB()])
models.append(['BernoulliNB', BernoulliNB()])
models.append(['Decision Tree', DecisionTreeClassifier(random_state=0)])
models.append(['Random Forest', RandomForestClassifier(random_state=0)])
models.append(['XGBoost', XGBClassifier(eval_metric= 'error')])

lst_1= []

for m in range(len(models)):
    lst_2= []
    model = models[m][1]
    model.fit(x_train_res, y_train_res)
    y_pred = model.predict(x_test)
    cm = confusion_matrix(y_test, y_pred)  #Confusion Matrix
    accuracies = cross_val_score(estimator = model, X = x_train_res, y = y_train_res, cv = 10)   #K-Fold Validation
    roc = roc_auc_score(y_test, y_pred)  #ROC AUC Score
    precision = precision_score(y_test, y_pred)  #Precision Score
    recall = recall_score(y_test, y_pred)  #Recall Score
    f1 = f1_score(y_test, y_pred)  #F1 Score
    print(models[m][0],':')
    print(cm)
    print('Accuracy Score: ',accuracy_score(y_test, y_pred))
    print('')
    print("K-Fold Validation Mean Accuracy: {:.2f} %".format(accuracies.mean()*100))
    print('')
    print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))
    print('')
    print('ROC AUC Score: {:.2f}'.format(roc))
    print('')
    print('Precision: {:.2f}'.format(precision))
    print('')
    print('Recall: {:.2f}'.format(recall))
    print('')
    print('F1: {:.2f}'.format(f1))
    print('-----------------------------------')
    print('')
    lst_2.append(models[m][0])
    lst_2.append((accuracy_score(y_test, y_pred))*100) 
    lst_2.append(accuracies.mean()*100)
    lst_2.append(accuracies.std()*100)
    lst_2.append(roc)
    lst_2.append(precision)
    lst_2.append(recall)
    lst_2.append(f1)
    lst_1.append(lst_2)
# Out:
# Logistic Regreesion :
# [[750 218]
#  [ 15  39]]
# Accuracy Score:  0.7720156555772995
#
# K-Fold Validation Mean Accuracy: 79.45 %
#
# Standard Deviation: 1.39 %
#
# ROC AUC Score: 0.75
#
# Precision: 0.15
#
# Recall: 0.72
#
# F1: 0.25
# -----------------------------------
#
# SVM :
# [[794 174]
#  [ 32  22]]
# Accuracy Score:  0.7984344422700587
#
# K-Fold Validation Mean Accuracy: 88.36 %
#
# Standard Deviation: 1.54 %
#
# ROC AUC Score: 0.61
#
# Precision: 0.11
#
# Recall: 0.41
#
# F1: 0.18
# -----------------------------------
#
# KNeighbors :
# [[837 131]
#  [ 36  18]]
# Accuracy Score:  0.8365949119373777
#
# K-Fold Validation Mean Accuracy: 90.77 %
#
# Standard Deviation: 0.87 %
#
# ROC AUC Score: 0.60
#
# Precision: 0.12
#
# Recall: 0.33
#
# F1: 0.18
# -----------------------------------
#
# GaussianNB :
# [[145 823]
#  [  2  52]]
# Accuracy Score:  0.19275929549902152
#
# K-Fold Validation Mean Accuracy: 57.33 %
#
# Standard Deviation: 0.86 %
#
# ROC AUC Score: 0.56
#
# Precision: 0.06
#
# Recall: 0.96
#
# F1: 0.11
# -----------------------------------
#
# BernoulliNB :
# [[574 394]
#  [  9  45]]
# Accuracy Score:  0.6056751467710372
#
# K-Fold Validation Mean Accuracy: 72.94 %
#
# Standard Deviation: 1.59 %
#
# ROC AUC Score: 0.71
#
# Precision: 0.10
#
# Recall: 0.83
#
# F1: 0.18
# -----------------------------------
#
# Decision Tree :
# [[872  96]
#  [ 47   7]]
# Accuracy Score:  0.860078277886497
#
# K-Fold Validation Mean Accuracy: 90.39 %
#
# Standard Deviation: 2.94 %
#
# ROC AUC Score: 0.52
#
# Precision: 0.07
#
# Recall: 0.13
#
# F1: 0.09
# -----------------------------------
#
# Random Forest :
# [[921  47]
#  [ 49   5]]
# Accuracy Score:  0.9060665362035225
#
# K-Fold Validation Mean Accuracy: 95.97 %
#
# Standard Deviation: 1.38 %
#
# ROC AUC Score: 0.52
#
# Precision: 0.10
#
# Recall: 0.09
#
# F1: 0.09
# -----------------------------------
#
# XGBoost :
# [[940  28]
#  [ 49   5]]
# Accuracy Score:  0.9246575342465754
#
# K-Fold Validation Mean Accuracy: 95.58 %
#
# Standard Deviation: 6.04 %
#
# ROC AUC Score: 0.53
#
# Precision: 0.15
#
# Recall: 0.09
#
# F1: 0.11
# -----------------------------------

# %%
df = pd.DataFrame(lst_1, columns= ['Model', 'Accuracy', 'K-Fold Mean Accuracy', 'Std. Deviation', 'ROC AUC', 'Precision', 'Recall', 'F1'])
df.sort_values(by= ['Accuracy', 'K-Fold Mean Accuracy'], inplace= True, ascending= False)
df
# Out:
#                  Model   Accuracy  K-Fold Mean Accuracy  Std. Deviation  \
# 7              XGBoost  92.465753             95.582779        6.036886
# 6        Random Forest  90.606654             95.967343        1.377559
# 5        Decision Tree  86.007828             90.393013        2.936513
# 2           KNeighbors  83.659491             90.765631        0.866181
# 1                  SVM  79.843444             88.363831        1.536875
# 0  Logistic Regreesion  77.201566             79.450089        1.386548
# 4          BernoulliNB  60.567515             72.938676        1.593421
# 3           GaussianNB  19.275930             57.333590        0.861249
#
#     ROC AUC  Precision    Recall        F1
# 7  0.531833   0.151515  0.092593  0.114943
# 6  0.522019   0.096154  0.092593  0.094340
# 5  0.515228   0.067961  0.129630  0.089172
# 2  0.599001   0.120805  0.333333  0.177340
# 1  0.613828   0.112245  0.407407  0.176000
# 0  0.748508   0.151751  0.722222  0.250804
# 4  0.713154   0.102506  0.833333  0.182556
# 3  0.556378   0.059429  0.962963  0.111948

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_models = [(LogisticRegression(),[{'C':[0.25,0.5,0.75,1],'random_state':[0]}]), 
               (KNeighborsClassifier(),[{'n_neighbors':[5,7,8,10], 'metric': ['euclidean', 'manhattan', 'chebyshev', 'minkowski']}]), 
               (SVC(),[{'C':[0.25,0.5,0.75,1],'kernel':['linear', 'rbf'],'random_state':[0]}]), 
               (GaussianNB(),[{'var_smoothing': [1e-09]}]), 
               (BernoulliNB(), [{'alpha': [0.25, 0.5, 1]}]), 
               (DecisionTreeClassifier(),[{'criterion':['gini','entropy'],'random_state':[0]}]), 
               (RandomForestClassifier(),[{'n_estimators':[100,150,200],'criterion':['gini','entropy'],'random_state':[0]}]), 
              (XGBClassifier(), [{'learning_rate': [0.01, 0.05, 0.1], 'eval_metric': ['error']}])]
for i,j in grid_models:
    grid = GridSearchCV(estimator=i,param_grid = j, scoring = 'accuracy',cv = 10)
    grid.fit(x_train_res, y_train_res)
    best_accuracy = grid.best_score_
    best_param = grid.best_params_
    print('{}:\nBest Accuracy : {:.2f}%'.format(i,best_accuracy*100))
    print('Best Parameters : ',best_param)
    print('')
    print('----------------')
    print('')
# Out:
# LogisticRegression():
# Best Accuracy : 79.45%
# Best Parameters :  {'C': 0.75, 'random_state': 0}
#
# ----------------
#
# KNeighborsClassifier():
# Best Accuracy : 91.92%
# Best Parameters :  {'metric': 'manhattan', 'n_neighbors': 5}
#
# ----------------
#
# SVC():
# Best Accuracy : 88.36%
# Best Parameters :  {'C': 1, 'kernel': 'rbf', 'random_state': 0}
#
# ----------------
#
# GaussianNB():
# Best Accuracy : 57.33%
# Best Parameters :  {'var_smoothing': 1e-09}
#
# ----------------
#
# BernoulliNB():
# Best Accuracy : 72.94%
# Best Parameters :  {'alpha': 0.25}
#
# ----------------
#
# DecisionTreeClassifier():
# Best Accuracy : 91.10%
# Best Parameters :  {'criterion': 'entropy', 'random_state': 0}
#
# ----------------
#
# RandomForestClassifier():
# Best Accuracy : 95.97%
# Best Parameters :  {'criterion': 'gini', 'n_estimators': 100, 'random_state': 0}
#
# ----------------
#
# XGBClassifier(base_score=None, booster=None, colsample_bylevel=None,
#               colsample_bynode=None, colsample_bytree=None, gamma=None,
#               gpu_id=None, importance_type='gain', interaction_constraints=None,
#               learning_rate=None, max_delta_step=None, max_depth=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               random_state=None, reg_alpha=None, reg_lambda=None,
#               scale_pos_weight=None, subsample=None, tree_method=None,
#               validate_parameters=None, verbosity=None):
# Best Accuracy : 93.45%
# Best Parameters :  {'eval_metric': 'error', 'learning_rate': 0.1}
#
# ----------------

# %%
classifier = RandomForestClassifier(criterion= 'gini', n_estimators= 100, random_state= 0)
classifier.fit(x_train_res, y_train_res)
y_pred = classifier.predict(x_test)
y_prob = classifier.predict_proba(x_test)[:,1]
cm = confusion_matrix(y_test, y_pred)

print(classification_report(y_test, y_pred))
print(f'ROC AUC score: {roc_auc_score(y_test, y_prob)}')
print('Accuracy Score: ',accuracy_score(y_test, y_pred))

# Visualizing Confusion Matrix
plt.figure(figsize = (8, 5))
sns.heatmap(cm, cmap = 'Blues', annot = True, fmt = 'd', linewidths = 5, cbar = False, annot_kws = {'fontsize': 15}, 
            yticklabels = ['No stroke', 'Stroke'], xticklabels = ['Predicted no stroke', 'Predicted stroke'])
plt.yticks(rotation = 0)
plt.show()

# Roc AUC Curve
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)

sns.set_theme(style = 'white')
plt.figure(figsize = (8, 8))
plt.plot(false_positive_rate,true_positive_rate, color = '#b01717', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1], linestyle = '--', color = '#174ab0')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend()
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       968
#            1       0.10      0.09      0.09        54
#
#     accuracy                           0.91      1022
#    macro avg       0.52      0.52      0.52      1022
# weighted avg       0.90      0.91      0.91      1022
#
# ROC AUC score: 0.7328397612488522
# Accuracy Score:  0.9060665362035225

# %%
classifier = XGBClassifier(eval_metric= 'error', learning_rate= 0.1)
classifier.fit(x_train_res, y_train_res)
y_pred = classifier.predict(x_test)
y_prob = classifier.predict_proba(x_test)[:,1]
cm = confusion_matrix(y_test, y_pred)

print(classification_report(y_test, y_pred))
print(f'ROC AUC score: {roc_auc_score(y_test, y_prob)}')
print('Accuracy Score: ',accuracy_score(y_test, y_pred))

# Visualizing Confusion Matrix
plt.figure(figsize = (8, 5))
sns.heatmap(cm, cmap = 'Blues', annot = True, fmt = 'd', linewidths = 5, cbar = False, annot_kws = {'fontsize': 15}, 
            yticklabels = ['No stroke', 'Stroke'], xticklabels = ['Predicted no stroke', 'Predicted stroke'])
plt.yticks(rotation = 0)
plt.show()

# Roc Curve
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(false_positive_rate, true_positive_rate)

sns.set_theme(style = 'white')
plt.figure(figsize = (8, 8))
plt.plot(false_positive_rate,true_positive_rate, color = '#b01717', label = 'AUC = %0.3f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1], linestyle = '--', color = '#174ab0')
plt.axis('tight')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94       968
#            1       0.11      0.17      0.13        54
#
#     accuracy                           0.89      1022
#    macro avg       0.53      0.55      0.54      1022
# weighted avg       0.91      0.89      0.90      1022
#
# ROC AUC score: 0.7473599632690542
# Accuracy Score:  0.8864970645792564
# Text(0.5, 0, 'False Positive Rate')

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from keras.regularizers import l2

# %%
def ann_classifier():
    ann = tf.keras.models.Sequential()
    ann.add(tf.keras.layers.Dense(units= 8, kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01), activation='relu'))
    ann.add(tf.keras.layers.Dense(units= 8, kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01), activation='relu'))
    tf.keras.layers.Dropout(0.6)
    ann.add(tf.keras.layers.Dense(units= 1, activation='sigmoid'))
    ann.compile(optimizer= 'adam', loss= 'binary_crossentropy', metrics= ['accuracy'])
    return ann
# Passing values to KerasClassifier 
ann = KerasClassifier(build_fn = ann_classifier, batch_size = 32, epochs = 50)

# %%
accuracies = cross_val_score(estimator = ann, X = x_train_res, y = y_train_res, cv = 5)
# Out:
# Epoch 1/50
# 195/195 [==============================] - 1s 1ms/step - loss: 0.8824 - accuracy: 0.6151
# Epoch 2/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.6484 - accuracy: 0.7790
# Epoch 3/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5465 - accuracy: 0.8195
# Epoch 4/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5007 - accuracy: 0.8300
# Epoch 5/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4740 - accuracy: 0.8281
# Epoch 6/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4632 - accuracy: 0.8351
# Epoch 7/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4432 - accuracy: 0.8404
# Epoch 8/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4500 - accuracy: 0.8321
# Epoch 9/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4314 - accuracy: 0.8426
# Epoch 10/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4249 - accuracy: 0.8494
# Epoch 11/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4240 - accuracy: 0.8455
# Epoch 12/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4230 - accuracy: 0.8418
# Epoch 13/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4260 - accuracy: 0.8435
# Epoch 14/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4135 - accuracy: 0.8491
# Epoch 15/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4203 - accuracy: 0.8458
# Epoch 16/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4081 - accuracy: 0.8527
# Epoch 17/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4172 - accuracy: 0.8485
# Epoch 18/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3980 - accuracy: 0.8577
# Epoch 19/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4030 - accuracy: 0.8574
# Epoch 20/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4094 - accuracy: 0.8473
# Epoch 21/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3954 - accuracy: 0.8584
# Epoch 22/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3921 - accuracy: 0.8619
# Epoch 23/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3896 - accuracy: 0.8653
# Epoch 24/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3930 - accuracy: 0.8617
# Epoch 25/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3965 - accuracy: 0.8593
# Epoch 26/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3891 - accuracy: 0.8616
# Epoch 27/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3903 - accuracy: 0.8601
# Epoch 28/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3838 - accuracy: 0.8673
# Epoch 29/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3887 - accuracy: 0.8625
# Epoch 30/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3809 - accuracy: 0.8641
# Epoch 31/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3870 - accuracy: 0.8631
# Epoch 32/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3908 - accuracy: 0.8589
# Epoch 33/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3736 - accuracy: 0.8722
# Epoch 34/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3737 - accuracy: 0.8726
# Epoch 35/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3809 - accuracy: 0.8702
# Epoch 36/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3772 - accuracy: 0.8741
# Epoch 37/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3820 - accuracy: 0.8714
# Epoch 38/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3721 - accuracy: 0.8760
# Epoch 39/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3667 - accuracy: 0.8766
# Epoch 40/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3712 - accuracy: 0.8757
# Epoch 41/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3627 - accuracy: 0.8794
# Epoch 42/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3699 - accuracy: 0.8731
# Epoch 43/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3720 - accuracy: 0.8767
# Epoch 44/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3798 - accuracy: 0.8669
# Epoch 45/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3729 - accuracy: 0.8758
# Epoch 46/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3661 - accuracy: 0.8798
# Epoch 47/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3644 - accuracy: 0.8795
# Epoch 48/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3586 - accuracy: 0.8810
# Epoch 49/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3605 - accuracy: 0.8837
# Epoch 50/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3679 - accuracy: 0.8772
# 49/49 [==============================] - 0s 922us/step - loss: 0.5750 - accuracy: 0.7202
# Epoch 1/50
# 195/195 [==============================] - 1s 1ms/step - loss: 0.9203 - accuracy: 0.5060
# Epoch 2/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.7020 - accuracy: 0.7123
# Epoch 3/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.6062 - accuracy: 0.7911
# Epoch 4/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5326 - accuracy: 0.8154
# Epoch 5/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4872 - accuracy: 0.8262
# Epoch 6/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4756 - accuracy: 0.8261
# Epoch 7/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4565 - accuracy: 0.8300
# Epoch 8/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4436 - accuracy: 0.8404
# Epoch 9/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4368 - accuracy: 0.8392
# Epoch 10/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4349 - accuracy: 0.8378
# Epoch 11/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4189 - accuracy: 0.8514
# Epoch 12/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4212 - accuracy: 0.8459
# Epoch 13/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4120 - accuracy: 0.8537
# Epoch 14/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4109 - accuracy: 0.8524
# Epoch 15/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4035 - accuracy: 0.8535
# Epoch 16/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4052 - accuracy: 0.8564
# Epoch 17/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4107 - accuracy: 0.8501
# Epoch 18/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4015 - accuracy: 0.8554
# Epoch 19/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3994 - accuracy: 0.8581
# Epoch 20/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3992 - accuracy: 0.8580
# Epoch 21/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3943 - accuracy: 0.8578
# Epoch 22/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3911 - accuracy: 0.8578
# Epoch 23/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3893 - accuracy: 0.8636
# Epoch 24/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3802 - accuracy: 0.8648
# Epoch 25/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3891 - accuracy: 0.8646
# Epoch 26/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3914 - accuracy: 0.8585
# Epoch 27/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3945 - accuracy: 0.8552
# Epoch 28/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3820 - accuracy: 0.8643
# Epoch 29/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3896 - accuracy: 0.8544
# Epoch 30/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3765 - accuracy: 0.8649
# Epoch 31/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3818 - accuracy: 0.8668
# Epoch 32/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3803 - accuracy: 0.8671
# Epoch 33/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3804 - accuracy: 0.8664
# Epoch 34/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3816 - accuracy: 0.8612
# Epoch 35/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3847 - accuracy: 0.8592
# Epoch 36/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3733 - accuracy: 0.8684
# Epoch 37/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3749 - accuracy: 0.8680
# Epoch 38/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3638 - accuracy: 0.8754
# Epoch 39/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3786 - accuracy: 0.8611
# Epoch 40/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3668 - accuracy: 0.8708
# Epoch 41/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3787 - accuracy: 0.8626
# Epoch 42/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3699 - accuracy: 0.8673
# Epoch 43/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3629 - accuracy: 0.8701
# Epoch 44/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3701 - accuracy: 0.8707
# Epoch 45/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3646 - accuracy: 0.8697
# Epoch 46/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3727 - accuracy: 0.8635
# Epoch 47/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3737 - accuracy: 0.8662
# Epoch 48/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3729 - accuracy: 0.8619
# Epoch 49/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3674 - accuracy: 0.8717
# Epoch 50/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3626 - accuracy: 0.8716
# 49/49 [==============================] - 0s 1ms/step - loss: 0.5084 - accuracy: 0.7566
# Epoch 1/50
# 195/195 [==============================] - 1s 1ms/step - loss: 0.8631 - accuracy: 0.5684
# Epoch 2/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.6890 - accuracy: 0.7008
# Epoch 3/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5535 - accuracy: 0.7860
# Epoch 4/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4977 - accuracy: 0.8139
# Epoch 5/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4800 - accuracy: 0.8052
# Epoch 6/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4597 - accuracy: 0.8196
# Epoch 7/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4591 - accuracy: 0.8176
# Epoch 8/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4582 - accuracy: 0.8140
# Epoch 9/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4540 - accuracy: 0.8143
# Epoch 10/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4405 - accuracy: 0.8260
# Epoch 11/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4412 - accuracy: 0.8184
# Epoch 12/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4372 - accuracy: 0.8199
# Epoch 13/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4407 - accuracy: 0.8211
# Epoch 14/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4399 - accuracy: 0.8165
# Epoch 15/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4209 - accuracy: 0.8293
# Epoch 16/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4339 - accuracy: 0.8213
# Epoch 17/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4179 - accuracy: 0.8316
# Epoch 18/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4155 - accuracy: 0.8364
# Epoch 19/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4202 - accuracy: 0.8294
# Epoch 20/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4162 - accuracy: 0.8353
# Epoch 21/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4101 - accuracy: 0.8335
# Epoch 22/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4081 - accuracy: 0.8400
# Epoch 23/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4098 - accuracy: 0.8438
# Epoch 24/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4181 - accuracy: 0.8323
# Epoch 25/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4135 - accuracy: 0.8347
# Epoch 26/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4070 - accuracy: 0.8402
# Epoch 27/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4096 - accuracy: 0.8424
# Epoch 28/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4191 - accuracy: 0.8293
# Epoch 29/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4045 - accuracy: 0.8385
# Epoch 30/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4140 - accuracy: 0.8324
# Epoch 31/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4033 - accuracy: 0.8435
# Epoch 32/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4010 - accuracy: 0.8378
# Epoch 33/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3888 - accuracy: 0.8460
# Epoch 34/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4006 - accuracy: 0.8382
# Epoch 35/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3950 - accuracy: 0.8470
# Epoch 36/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4051 - accuracy: 0.8368
# Epoch 37/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3951 - accuracy: 0.8421
# Epoch 38/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3971 - accuracy: 0.8478
# Epoch 39/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3896 - accuracy: 0.8444
# Epoch 40/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3920 - accuracy: 0.8451
# Epoch 41/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3943 - accuracy: 0.8428
# Epoch 42/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3856 - accuracy: 0.8456
# Epoch 43/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3900 - accuracy: 0.8480
# Epoch 44/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3931 - accuracy: 0.8444
# Epoch 45/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3752 - accuracy: 0.8598
# Epoch 46/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3860 - accuracy: 0.8465
# Epoch 47/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3837 - accuracy: 0.8537
# Epoch 48/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3805 - accuracy: 0.8509
# Epoch 49/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3860 - accuracy: 0.8491
# Epoch 50/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3864 - accuracy: 0.8514
# 49/49 [==============================] - 0s 878us/step - loss: 0.3992 - accuracy: 0.8324
# Epoch 1/50
# 195/195 [==============================] - 1s 1ms/step - loss: 0.9161 - accuracy: 0.4412
# Epoch 2/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.7533 - accuracy: 0.6586
# Epoch 3/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.6206 - accuracy: 0.7397
# Epoch 4/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5377 - accuracy: 0.7766
# Epoch 5/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4963 - accuracy: 0.7898
# Epoch 6/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4829 - accuracy: 0.7893
# Epoch 7/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4762 - accuracy: 0.7958
# Epoch 8/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4649 - accuracy: 0.7946
# Epoch 9/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4609 - accuracy: 0.7985
# Epoch 10/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4569 - accuracy: 0.8033
# Epoch 11/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4597 - accuracy: 0.7987
# Epoch 12/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4562 - accuracy: 0.8034
# Epoch 13/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4476 - accuracy: 0.8059
# Epoch 14/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4490 - accuracy: 0.8053
# Epoch 15/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4407 - accuracy: 0.8052
# Epoch 16/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4436 - accuracy: 0.8073
# Epoch 17/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4357 - accuracy: 0.8115
# Epoch 18/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4342 - accuracy: 0.8096
# Epoch 19/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4341 - accuracy: 0.8154
# Epoch 20/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4343 - accuracy: 0.8058
# Epoch 21/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4359 - accuracy: 0.8118
# Epoch 22/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4272 - accuracy: 0.8147
# Epoch 23/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4302 - accuracy: 0.8174
# Epoch 24/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4277 - accuracy: 0.8121
# Epoch 25/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4363 - accuracy: 0.8092
# Epoch 26/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4276 - accuracy: 0.8122
# Epoch 27/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4116 - accuracy: 0.8267
# Epoch 28/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4224 - accuracy: 0.8187
# Epoch 29/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4170 - accuracy: 0.8267
# Epoch 30/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4216 - accuracy: 0.8215
# Epoch 31/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4212 - accuracy: 0.8159
# Epoch 32/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4136 - accuracy: 0.8190
# Epoch 33/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4167 - accuracy: 0.8236
# Epoch 34/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4173 - accuracy: 0.8267
# Epoch 35/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4092 - accuracy: 0.8273
# Epoch 36/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4239 - accuracy: 0.8159
# Epoch 37/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4240 - accuracy: 0.8181
# Epoch 38/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4147 - accuracy: 0.8159
# Epoch 39/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4223 - accuracy: 0.8145
# Epoch 40/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4037 - accuracy: 0.8273
# Epoch 41/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4112 - accuracy: 0.8223
# Epoch 42/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3991 - accuracy: 0.8260
# Epoch 43/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4070 - accuracy: 0.8203
# Epoch 44/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4001 - accuracy: 0.8311
# Epoch 45/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4073 - accuracy: 0.8274
# Epoch 46/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3987 - accuracy: 0.8333
# Epoch 47/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3959 - accuracy: 0.8310
# Epoch 48/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3974 - accuracy: 0.8285
# Epoch 49/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3924 - accuracy: 0.8335
# Epoch 50/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3973 - accuracy: 0.8300
# 49/49 [==============================] - 1s 1ms/step - loss: 0.4454 - accuracy: 0.8568
# Epoch 1/50
# 195/195 [==============================] - 1s 1ms/step - loss: 0.8609 - accuracy: 0.5552
# Epoch 2/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.6688 - accuracy: 0.7453
# Epoch 3/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5670 - accuracy: 0.7811
# Epoch 4/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.5126 - accuracy: 0.7922
# Epoch 5/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4931 - accuracy: 0.7908
# Epoch 6/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4769 - accuracy: 0.7994
# Epoch 7/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4688 - accuracy: 0.8004
# Epoch 8/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4673 - accuracy: 0.8029
# Epoch 9/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4597 - accuracy: 0.8006
# Epoch 10/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4609 - accuracy: 0.7994
# Epoch 11/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4504 - accuracy: 0.8093
# Epoch 12/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4436 - accuracy: 0.8166
# Epoch 13/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4335 - accuracy: 0.8182
# Epoch 14/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4484 - accuracy: 0.8016
# Epoch 15/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4342 - accuracy: 0.8177
# Epoch 16/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4320 - accuracy: 0.8190
# Epoch 17/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4200 - accuracy: 0.8273
# Epoch 18/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4255 - accuracy: 0.8243
# Epoch 19/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4203 - accuracy: 0.8163
# Epoch 20/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4239 - accuracy: 0.8271
# Epoch 21/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4225 - accuracy: 0.8228
# Epoch 22/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4150 - accuracy: 0.8291
# Epoch 23/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4042 - accuracy: 0.8346
# Epoch 24/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4090 - accuracy: 0.8294
# Epoch 25/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4112 - accuracy: 0.8272
# Epoch 26/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4032 - accuracy: 0.8302
# Epoch 27/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3991 - accuracy: 0.8335
# Epoch 28/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4057 - accuracy: 0.8303
# Epoch 29/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4090 - accuracy: 0.8310
# Epoch 30/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4144 - accuracy: 0.8198
# Epoch 31/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4013 - accuracy: 0.8386
# Epoch 32/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4028 - accuracy: 0.8321
# Epoch 33/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4087 - accuracy: 0.8340
# Epoch 34/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3975 - accuracy: 0.8321
# Epoch 35/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4028 - accuracy: 0.8309
# Epoch 36/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.4006 - accuracy: 0.8306
# Epoch 37/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3964 - accuracy: 0.8341
# Epoch 38/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3861 - accuracy: 0.8446
# Epoch 39/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3942 - accuracy: 0.8356
# Epoch 40/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3849 - accuracy: 0.8397
# Epoch 41/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3897 - accuracy: 0.8378
# Epoch 42/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3949 - accuracy: 0.8360
# Epoch 43/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3946 - accuracy: 0.8433
# Epoch 44/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3903 - accuracy: 0.8375
# Epoch 45/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3905 - accuracy: 0.8389
# Epoch 46/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3828 - accuracy: 0.8437
# Epoch 47/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3829 - accuracy: 0.8458
# Epoch 48/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3881 - accuracy: 0.8373
# Epoch 49/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3839 - accuracy: 0.8440
# Epoch 50/50
# 195/195 [==============================] - 0s 1ms/step - loss: 0.3815 - accuracy: 0.8493
# 49/49 [==============================] - 0s 979us/step - loss: 0.5114 - accuracy: 0.8317

# %%
mean = accuracies.mean()
std_deviation = accuracies.std()
print("Accuracy: {:.2f} %".format(mean*100))
print("Standard Deviation: {:.2f} %".format(std_deviation*100))
# Out:
# Accuracy: 79.95 %
# Standard Deviation: 5.20 %
