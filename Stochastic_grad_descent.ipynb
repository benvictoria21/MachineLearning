# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from time import time
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
sgd_class = SGDClassifier(alpha=0.001,loss='hinge',max_iter=100,tol=0.001,n_jobs=-1,early_stopping=True,n_iter_no_change=2)
hinge_acc=[]
hinge_time=[]
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
for size in [int(10**(0.2*i)) for i in range(15,31)]:
    prob=make_classification(n_samples=size,n_features=50, n_informative=45,n_classes=2,class_sep=0.75,random_state=101)
    X,y=prob
    X = scaler.fit_transform(X)
    print("Size of the problem: ",X.shape)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    t1 = time()
    sgd_class.fit(X_train,y_train)
    t2 = time()
    t_delta=round(1e3*(t2-t1),3)
    hinge_time.append(t_delta)
    print(f"Took {t_delta} milliseconds")
    acc = accuracy_score(y_test,sgd_class.predict(X_test))
    hinge_acc.append(acc)
    print("Accuracy on the test set:", round(acc,3))
    print()
# Out:
# Size of the problem:  (1000, 50)
# Took 7.335 milliseconds
# Accuracy on the test set: 0.693
#
# Size of the problem:  (1584, 50)
# Took 8.545 milliseconds
# Accuracy on the test set: 0.742
#
# Size of the problem:  (2511, 50)
# Took 9.866 milliseconds
# Accuracy on the test set: 0.715
#
# Size of the problem:  (3981, 50)
# Took 14.146 milliseconds
# Accuracy on the test set: 0.718
#
# Size of the problem:  (6309, 50)
# Took 15.191 milliseconds
# Accuracy on the test set: 0.751
#
# Size of the problem:  (10000, 50)
# Took 28.727 milliseconds
# Accuracy on the test set: 0.774
#
# Size of the problem:  (15848, 50)
# Took 44.287 milliseconds
# Accuracy on the test set: 0.76
#
# Size of the problem:  (25118, 50)
# Took 56.525 milliseconds
# Accuracy on the test set: 0.776
#
# Size of the problem:  (39810, 50)
# Took 91.63 milliseconds
# Accuracy on the test set: 0.804
#
# Size of the problem:  (63095, 50)
# Took 112.727 milliseconds
# Accuracy on the test set: 0.79
#
# Size of the problem:  (100000, 50)
# Took 178.504 milliseconds
# Accuracy on the test set: 0.816
#
# Size of the problem:  (158489, 50)
# Took 309.48 milliseconds
# Accuracy on the test set: 0.773
#
# Size of the problem:  (251188, 50)
# Took 603.367 milliseconds
# Accuracy on the test set: 0.811
#
# Size of the problem:  (398107, 50)
# Took 727.274 milliseconds
# Accuracy on the test set: 0.809
#
# Size of the problem:  (630957, 50)
# Took 1128.811 milliseconds
# Accuracy on the test set: 0.789
#
# Size of the problem:  (1000000, 50)
# Took 1801.862 milliseconds
# Accuracy on the test set: 0.809

# %%
sgd_class = SGDClassifier(alpha=0.001,loss='hinge',max_iter=100,tol=0.001,n_jobs=-1,early_stopping=True,n_iter_no_change=2)
log_acc=[]
log_time=[]
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
for size in [int(10**(0.2*i)) for i in range(15,31)]:
    prob=make_classification(n_samples=size,n_features=50, n_informative=45,n_classes=2,class_sep=0.75,random_state=101)
    X,y=prob
    X = scaler.fit_transform(X)
    print("Size of the problem: ",X.shape)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    t1 = time()
    sgd_class.fit(X_train,y_train)
    t2 = time()
    t_delta=round(1e3*(t2-t1),3)
    log_time.append(t_delta)
    print(f"Took {t_delta} milliseconds")
    acc = accuracy_score(y_test,sgd_class.predict(X_test))
    log_acc.append(acc)
    print("Accuracy on the test set:", round(acc,3))
    print()
# Out:
# Size of the problem:  (1000, 50)
# Took 6.59 milliseconds
# Accuracy on the test set: 0.737
#
# Size of the problem:  (1584, 50)
# Took 6.849 milliseconds
# Accuracy on the test set: 0.752
#
# Size of the problem:  (2511, 50)
# Took 8.882 milliseconds
# Accuracy on the test set: 0.706
#
# Size of the problem:  (3981, 50)
# Took 12.145 milliseconds
# Accuracy on the test set: 0.718
#
# Size of the problem:  (6309, 50)
# Took 14.637 milliseconds
# Accuracy on the test set: 0.712
#
# Size of the problem:  (10000, 50)
# Took 22.024 milliseconds
# Accuracy on the test set: 0.746
#
# Size of the problem:  (15848, 50)
# Took 36.695 milliseconds
# Accuracy on the test set: 0.77
#
# Size of the problem:  (25118, 50)
# Took 55.191 milliseconds
# Accuracy on the test set: 0.749
#
# Size of the problem:  (39810, 50)
# Took 109.084 milliseconds
# Accuracy on the test set: 0.802
#
# Size of the problem:  (63095, 50)
# Took 113.795 milliseconds
# Accuracy on the test set: 0.781
#
# Size of the problem:  (100000, 50)
# Took 178.535 milliseconds
# Accuracy on the test set: 0.816
#
# Size of the problem:  (158489, 50)
# Took 299.435 milliseconds
# Accuracy on the test set: 0.778
#
# Size of the problem:  (251188, 50)
# Took 489.81 milliseconds
# Accuracy on the test set: 0.811
#
# Size of the problem:  (398107, 50)
# Took 749.483 milliseconds
# Accuracy on the test set: 0.812
#
# Size of the problem:  (630957, 50)
# Took 1135.966 milliseconds
# Accuracy on the test set: 0.791
#
# Size of the problem:  (1000000, 50)
# Took 1875.512 milliseconds
# Accuracy on the test set: 0.809

# %%
sgd_class = SGDClassifier(alpha=0.001,loss='hinge',max_iter=100,tol=0.001,n_jobs=-1,early_stopping=True,n_iter_no_change=2)
perceptron_acc=[]
perceptron_time=[]
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
for size in [int(10**(0.2*i)) for i in range(15,31)]:
    prob=make_classification(n_samples=size,n_features=50, n_informative=45,n_classes=2,class_sep=0.75,random_state=101)
    X,y=prob
    X = scaler.fit_transform(X)
    print("Size of the problem: ",X.shape)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    t1 = time()
    sgd_class.fit(X_train,y_train)
    t2 = time()
    t_delta=round(1e3*(t2-t1),3)
    perceptron_time.append(t_delta)
    print(f"Took {t_delta} milliseconds")
    acc = accuracy_score(y_test,sgd_class.predict(X_test))
    perceptron_acc.append(acc)
    print("Accuracy on the test set:", round(acc,3))
    print()
# Out:
# Size of the problem:  (1000, 50)
# Took 5.329 milliseconds
# Accuracy on the test set: 0.753
#
# Size of the problem:  (1584, 50)
# Took 6.053 milliseconds
# Accuracy on the test set: 0.685
#
# Size of the problem:  (2511, 50)
# Took 7.767 milliseconds
# Accuracy on the test set: 0.692
#
# Size of the problem:  (3981, 50)
# Took 11.119 milliseconds
# Accuracy on the test set: 0.696
#
# Size of the problem:  (6309, 50)
# Took 15.427 milliseconds
# Accuracy on the test set: 0.736
#
# Size of the problem:  (10000, 50)
# Took 21.489 milliseconds
# Accuracy on the test set: 0.754
#
# Size of the problem:  (15848, 50)
# Took 36.603 milliseconds
# Accuracy on the test set: 0.771
#
# Size of the problem:  (25118, 50)
# Took 52.939 milliseconds
# Accuracy on the test set: 0.771
#
# Size of the problem:  (39810, 50)
# Took 73.167 milliseconds
# Accuracy on the test set: 0.797
#
# Size of the problem:  (63095, 50)
# Took 112.824 milliseconds
# Accuracy on the test set: 0.78
#
# Size of the problem:  (100000, 50)
# Took 181.821 milliseconds
# Accuracy on the test set: 0.808
#
# Size of the problem:  (158489, 50)
# Took 302.62 milliseconds
# Accuracy on the test set: 0.774
#
# Size of the problem:  (251188, 50)
# Took 491.864 milliseconds
# Accuracy on the test set: 0.809
#
# Size of the problem:  (398107, 50)
# Took 734.839 milliseconds
# Accuracy on the test set: 0.809
#
# Size of the problem:  (630957, 50)
# Took 1135.855 milliseconds
# Accuracy on the test set: 0.791
#
# Size of the problem:  (1000000, 50)
# Took 1814.672 milliseconds
# Accuracy on the test set: 0.809

# %%
rf = RandomForestClassifier(n_estimators=20,max_depth=5,min_samples_leaf=5,min_samples_split=10,n_jobs=-1)
rf_acc=[]
rf_time=[]
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
for size in [int(10**(0.2*i)) for i in range(15,31)]:
    prob=make_classification(n_samples=size,n_features=50, n_informative=45,n_classes=2,class_sep=0.75,random_state=101)
    X,y=prob
    X = scaler.fit_transform(X)
    print("Size of the problem: ",X.shape)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    t1 = time()
    rf.fit(X_train,y_train)
    t2 = time()
    t_delta=round(1e3*(t2-t1),3)
    rf_time.append(t_delta)
    print(f"Took {t_delta} milliseconds")
    acc = accuracy_score(y_test,rf.predict(X_test))
    rf_acc.append(acc)
    print("Accuracy:", round(acc,3))
    print()
# Out:
# Size of the problem:  (1000, 50)
# Took 116.311 milliseconds
# Accuracy: 0.75
#
# Size of the problem:  (1584, 50)
# Took 220.259 milliseconds
# Accuracy: 0.735
#
# Size of the problem:  (2511, 50)
# Took 219.596 milliseconds
# Accuracy: 0.775
#
# Size of the problem:  (3981, 50)
# Took 221.288 milliseconds
# Accuracy: 0.776
#
# Size of the problem:  (6309, 50)
# Took 320.973 milliseconds
# Accuracy: 0.797
#
# Size of the problem:  (10000, 50)
# Took 422.192 milliseconds
# Accuracy: 0.818
#
# Size of the problem:  (15848, 50)
# Took 628.102 milliseconds
# Accuracy: 0.806
#
# Size of the problem:  (25118, 50)
# Took 920.405 milliseconds
# Accuracy: 0.815
#
# Size of the problem:  (39810, 50)
# Took 1419.514 milliseconds
# Accuracy: 0.82
#
# Size of the problem:  (63095, 50)
# Took 2322.623 milliseconds
# Accuracy: 0.801
#
# Size of the problem:  (100000, 50)
# Took 3829.978 milliseconds
# Accuracy: 0.825
#
# Size of the problem:  (158489, 50)
# Took 6342.033 milliseconds
# Accuracy: 0.809
#
# Size of the problem:  (251188, 50)
# Took 10962.484 milliseconds
# Accuracy: 0.814
#
# Size of the problem:  (398107, 50)
# Took 18902.564 milliseconds
# Accuracy: 0.828
#
# Size of the problem:  (630957, 50)
# Took 32468.159 milliseconds
# Accuracy: 0.804
#
# Size of the problem:  (1000000, 50)

# %%
def plot_var(var,var_name):
    size =np.array([int(10**(0.2*i)) for i in range(15,31)])
    plt.figure(figsize=(8,5))
    plt.title(f"{var_name} with training set size",fontsize=18)
    plt.semilogx(size*0.7,var,marker='o',color='k',lw=3,markersize=12)
    plt.grid(True)
    plt.xticks(fontsize=15)
    plt.yticks(fontsize=15)
    plt.xlabel("Training set size",fontsize=15)
    plt.ylabel("Training time (milliseconds)",fontsize=15)

# %%
plot_var(hinge_time,'Hinge loss time')
plot_var(log_time,'Logistic loss time')
plot_var(perceptron_time,'Perceptron algorithm time')
plot_var(rf_time,'Random Forest time')
plt.show()

# %%
plot_var(hinge_acc,'Hinge loss accuracy')
plot_var(log_acc,'Logistic loss accuracy')
plot_var(perceptron_acc,'Perceptron algorithm accuracy')
plot_var(rf_acc,'Random Forest accuracy')
plt.show()
